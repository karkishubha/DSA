# %% [markdown]
# # Your Name: Shubha Raj Karki
# # Student ID:24128459

# %% [markdown]
# # Linked Lists

# %%
class Node:
    def __init__(self):
        self.next = None
        self.prev = None
        self.info = 0

# %% [markdown]
# **QN6) Complete the following program.**

# %% [markdown]
# Node class with three instance variables: `next`, `prev`, and `info`. The `__init__` method sets the initial values of these instance variables to `None`, `None`, and `0`, respectively.

# %%
class SLList:
  def __init__(self):
    self.first = None
    self.last = None

  def insert_beg(self):
    element = int(input("Enter element to insert: "))
    node = Node()
    node.info = element
    if self.first == None:
      self.first = self.last = node
      node.next = None
    else:
      #Your code
      node.next=self.first

  def insert_end(self):
    element = int(input("Enter element to insert: "))
    node = Node()
    node.info = element
    if self.first == None:
      self.first = self.last = node
      node.next = None
    else:
       #Your code
       node.next=None
       self.last.next=node
       node=self.last


  def insert_spec_pos(self):
    element = int(input("Enter element to insert: "))
    node = Node()
    node.info = element
    pos = int(input("Enter position to insert: "))
    if self.first == None:
      self.first = self.last = node
      node.next = None
    else:
      temp=self.first
      for i in range (1,pos-1,1):
        temp=temp.next




      node.next=temp.next
      temp.next=node



  def delete_first(self):
    if self.first == None:
      print("List is empty")
    elif self.first == self.last:
      self.first = None
      self.last = None
    else:
       #Your code
       self.first=self.first.next

  def delete_end(self):
    if self.first == None:
      print("List is empty")
    elif self.first == self.last:
      self.first = None
      self.last = None
    else:
       #Your code
       temp=self.first
       while (temp.next!=None):
        temp=temp.next
       temp.next=None
       self.last=temp


  def delete_spec_pos(self):
    if self.first == None:
      print("List is empty")
    elif self.first == self.last:
      self.first = None
      self.last = None
    else:
       #Your code
       pos = int(input("Enter position of item to delete: "))
       temp=self.first
       for i in range(1,pos):
        temp=temp.next
       temp.next=(temp.next).next
       print(f" The element of position: {pos} has been deleted.")



  def search(self):
    element = int(input("Enter element to search: "))
    temp = self.first
    pos = 1
    while temp != None:
      if temp.info == element:
        print("Element found at position:", pos)
        break
      temp = temp.next
      pos += 1
    if temp == None:
      print("Element not found in the list")

  def display(self):
    if self.first == None:
      print("List is empty")
    else:
      temp = self.first
      while temp != None:
        print(temp.info, "  ", end='')
        temp = temp.next
      print("")
lst = SLList()

while True:
  print("1. Insert at beginning")
  print("2. Insert at end")
  print("3. Insert at specific position")
  print("4. Delete first node")
  print("5. Delete last node")
  print("6. Delete node at specific position")
  print("7. Search element")
  print("8. Display list")
  print("9. Exit")
  choice = int(input("Enter your choice: "))
  if choice == 9:
    break
  elif choice == 1:
    lst.insert_beg()
  elif choice == 2:
    lst.insert_end()
  elif choice == 3:
    lst.insert_spec_pos()
  elif choice == 4:
    lst.delete_first()
  elif choice == 5:
    lst.delete_end()
  elif choice == 6:
    lst.delete_spec_pos()
  elif choice == 7:
    lst.search()
  elif choice == 8:
    lst.display()
  else:
    print("Wrong choice")
    print("Bye!")
# Out:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at specific position
# 4. Delete first node
# 5. Delete last node
# 6. Delete node at specific position
# 7. Search element
# 8. Display list
# 9. Exit
# Enter your choice: 1
# Enter element to insert: 100
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at specific position
# 4. Delete first node
# 5. Delete last node
# 6. Delete node at specific position
# 7. Search element
# 8. Display list
# 9. Exit
# Enter your choice: 2
# Enter element to insert: 200
# 200 has been inserted at the end.
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at specific position
# 4. Delete first node
# 5. Delete last node
# 6. Delete node at specific position
# 7. Search element
# 8. Display list
# 9. Exit
# Enter your choice: 3
# Enter element to insert: 300
# Enter position to insert: 2
# 300 has been inserted at the given position: 2.
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at specific position
# 4. Delete first node
# 5. Delete last node
# 6. Delete node at specific position
# 7. Search element
# 8. Display list
# 9. Exit
# Enter your choice: 6
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at specific position
# 4. Delete first node
# 5. Delete last node
# 6. Delete node at specific position
# 7. Search element
# 8. Display list
# 9. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-2d9eede46e58> in <cell line: 120>()
#     128   print("8. Display list")
#     129   print("9. Exit")
# --> 130   choice = int(input("Enter your choice: "))
#     131   if choice == 9:
#     132     print("-----GOODBYE-----")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# **QN7) Please verify the program below:** Which one is best? Earlier or this one? Justify

# %%
class SLList:
    def __init__(self):
        self.first = None
        self.last = None
        self.length = 0

    def insert(self, element, pos=None):
        node = Node()
        node.info = element
        if self.first is None:
            self.first = self.last = node
            node.next = None
        elif pos == 1:
            node.next = self.first
            self.first = node
        elif pos is None or pos == self.length + 1:
            self.last.next = node
            self.last = node
            node.next = None
        elif 1 < pos <= self.length:
            temp = self.first
            for i in range(1, pos - 1):
                temp = temp.next
            node.next = temp.next
            temp.next = node
        self.length += 1

    def delete(self, pos=None):
      if self.first is None:
        print("List is empty")
      elif pos == 1:
        self.first = self.first.next
        if self.first is None:
            self.last = None
        self.length -= 1
      elif pos == self.length:
        if self.first == self.last:
            self.first = self.last = None
        else:
            temp = self.first
            while temp.next != self.last:
                temp = temp.next
            temp.next = None
            self.last = temp
        self.length -= 1
      elif 0 < pos < self.length:
        temp = self.first
        for i in range(1, pos - 1):
            temp = temp.next
        temp.next = temp.next.next
        self.length -= 1
        if pos == self.length:
            self.last = temp
      else:
        print("Invalid position")


    def search(self, element):
        temp = self.first
        pos = 1
        while temp is not None:
            if temp.info == element:
                print("Element found at position:", pos)
                break
            temp = temp.next
            pos += 1
        if temp is None:
            print("Element not found in the list")

    def display(self):
        if self.first is None:
            print("List is empty")
        else:
            temp = self.first
            while temp is not None:
                print(temp.info, "  ", end='')
                temp = temp.next
            print("")

lst = SLList()

while True:
    print("1. Insert at beginning")
    print("2. Insert at end")
    print("3. Insert at specific position")
    print("4. Delete first node")
    print("5. Delete last node")
    print("6. Delete node at specific position")
    print("7. Search element")
    print("8. Display list")
    print("9. Exit")
    choice = int(input("Enter your choice: "))
    if choice == 9:
      break
    elif choice == 1:
      element = int(input("Enter element to be inserted: "))
      lst.insert(element, 1)
    elif choice == 2:
      element = int(input("Enter element to be inserted: "))
      lst.insert(element)
    elif choice == 3:
      element = int(input("Enter element to be inserted: "))
      pos = int(input("Enter position at which element is to be inserted: "))
      lst.insert(element,pos)
    elif choice == 4:
      lst.delete(1)
    elif choice == 5:
      lst.delete(lst.length-1)
    elif choice == 6:
      pos = int(input("Enter position of element to be deleted: "))
      lst.delete(pos)
    elif choice == 7:
      element = int(input("Enter element to search: "))
      lst.search(element)
    elif choice == 8:
      lst.display()
    else:
      print("Wrong choice")
      print("Bye!")
# Out:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at specific position
# 4. Delete first node
# 5. Delete last node
# 6. Delete node at specific position
# 7. Search element
# 8. Display list
# 9. Exit

# %% [markdown]
# * I would prefer this code rather than the earlier one beacuse this code seems to use simpler and lesser functions  than the earlier one. Earlier code used multiple functions to complete multiple tasks but this code uses only two function for insertion and deletion and uses conditional statement inside those function for individual tasks. The value of position was asked inside the function in the earlier code but in this code the value is asked later on while using conditional statement.

# %% [markdown]
# **QN8) Complete the following program.**

# %%
from types import NotImplementedType
class DoublyLinkListDemo:
  def __init__(self):
      self.first = None
      self.last = None

  def insertBeg(self):
      element = int(input("Enter Data Item to Insert: "))
      node = Node()
      node.info = element
      if self.first is None:
          self.first = node
          self.last = node
          node.next = None
          node.prev = None
      else:
          node.prev=None
          node.next=self.first
          self.first.prev=node
          self.first=node


  def insertEnd(self):
      element = int(input("Enter Data Item to Insert: "))
      node = Node()
      node.info = element
      if self.first is None:
          self.first = node
          self.last = node
          node.next = None
          node.prev = None
      else:
          self.last.next=node
          node.prev=self.last
          node.next=None
          self.last=node



  def insertAtSpecificPosition(self):
      element = int(input("Enter Data Item to Insert: "))
      node = Node()
      node.info = element
      pos = int(input("Which Position You Want to Insert? "))
      if self.first is None:
          self.first = node
          self.last = node
          node.next = None
          node.prev = None
      else:
        temp=self.first
        for i in range(1,(pos-1),1):
          temp=temp.next

        node.prev=temp
        node.next=temp.next
        temp.next.prev=node
        temp.next=node



  def deleteFirst(self):
      if self.first is None:
          print("Linked List is Empty")
      elif self.first == self.last:
          self.first = None
          self.last = None
      else:
          self.first=self.first.next
          self.first.prev=None

  def deleteEnd(self):
      if self.first is None:
          print("Linked List is Empty")
      elif self.first == self.last:
          self.first = None
          self.last = None
          print("Last Node is Removed ")
      else:
          self.last=self.last.prev
          self.last.next=None
          print("Last Node is Removed ")


  def deleteAtSpecificPosition(self):

      if self.first is None:
          print("Linked List is Empty")
      elif self.first == self.last:
          self.first = None
          self.last = None
          print("Node is Removed ")
      else:
        pos = int(input("Which Position You Want to Delete? "))
        temp=self.first
        for i in range(1,pos,1):
          temp=temp.next
        (temp.next).prev=temp.prev
        temp.prev.next=temp.next


  def searchItem(self):
      if self.first is None:
          print("Linked List is Empty")
      else:
          element = int(input("Which Element You Want to Search? "))
          temp = self.first
          position = 0
          while temp is not None:
              if temp.info == element:
                  print("Element Found at position =",position)
                  break
              temp = temp.next
              position += 1
          if temp is None:
              print(element," Not Found on the Linked List")

  def displayAllItems(self):
      if self.first is None:
          print("Linked List is Empty")
      else:
          temp = self.first
          print("Elements in Linked List Are:")
          print("===========================================================")
          while temp is not None:
              print(temp.info, "  ", end = "")
              temp = temp.next
          print("\n")

dllist = DoublyLinkListDemo()
while True:
  print("===========================================================")
  print("Press 1 for Insert at Begining")
  print("Press 2 for Insert at End")
  print("Press 3 for Insert at Specific Position in List")
  print("Press 4 for Delete First Node")
  print("Press 5 for Delete Last Node")
  print("Press 6 for Delete Specific Node")
  print("Press 7 for Searching Specific Item in Linked List")
  print("Press 8 for Displaying all Items in Linked List")
  print("Enter 9 for Exit")
  print("===========================================================")

  choice = int(input("Enter your choice: "))
  if choice == 9:
    break
  elif choice == 1:
    dllist.insertBeg()
  elif choice == 2:
    dllist.insertEnd()
  elif choice == 3:
    dllist.insertAtSpecificPosition()
  elif choice == 4:
    dllist.deleteFirst()
  elif choice == 5:
    dllist.deleteEnd()
  elif choice == 6:
    dllist.deleteAtSpecificPosition()
  elif choice == 7:
    dllist.searchItem()
  elif choice == 8:
    dllist.displayAllItems()
  else:
    print("Wrong choice")
    print("Bye!")
# Out:
# ===========================================================
# Press 1 for Insert at Begining
# Press 2 for Insert at End
# Press 3 for Insert at Specific Position in List
# Press 4 for Delete First Node
# Press 5 for Delete Last Node
# Press 6 for Delete Specific Node
# Press 7 for Searching Specific Item in Linked List
# Press 8 for Displaying all Items in Linked List
# Enter 9 for Exit
# ===========================================================
# Linked List is Empty
# ===========================================================
# Press 1 for Insert at Begining
# Press 2 for Insert at End
# Press 3 for Insert at Specific Position in List
# Press 4 for Delete First Node
# Press 5 for Delete Last Node
# Press 6 for Delete Specific Node
# Press 7 for Searching Specific Item in Linked List
# Press 8 for Displaying all Items in Linked List
# Enter 9 for Exit
# ===========================================================

# %% [markdown]
# H/W **QN9) Can you optimize the above code?**

# %% [markdown]
# # Yes i can by using the similar option used for the singly linked list

# %%
#Your code
class SLList:
    def __init__(self):
        self.first = None
        self.last = None

        self.length = 0

    def insert(self, element, pos=None):
        node = Node()
        node.info = element
        if self.first is None:
            self.first = self.last = node
            node.next = None
        elif pos == 1:
            node.prev=None
            node.next=self.first
            self.first.prev=node
            self.first=node
        elif pos is None or pos == self.length + 1:
          self.last.next=node
          node.prev=self.last
          node.next=None
          self.last=node

        elif 1 < pos <= self.length:
            temp = self.first
            for i in range(1,pos-1,1):
              temp=temp.next

            node.prev=temp
            node.next=temp.next
            (temp.next).prev=node
            temp.next=node
        self.length += 1

    def delete(self, pos=None):
      if self.first is None:
        print("List is empty")
      elif pos == 1:
        self.first = self.first.next
        self.first.prev=None
        if self.first is None:
            self.last = None
        self.length -= 1
      elif pos == self.length:
        if self.first == self.last:
            self.first = self.last = None
        else:
            temp = self.first
            while temp.next != self.last:
                temp = temp.next
            temp.next.prev=None
            temp.next = None
            self.last = temp
        self.length -= 1
      elif 0 < pos < self.length:
        temp=self.first
        for i in range(1,pos,1):
          temp=temp.next

        (temp.next).prev=temp.prev
        temp.prev.next=temp.next
      else:
        print("Invalid position")


    def search(self, element):
        temp = self.first
        pos = 1
        while temp is not None:
            if temp.info == element:
                print("Element found at position:", pos)
                break
            temp = temp.next
            pos += 1
        if temp is None:
            print("Element not found in the list")

    def display(self):
        if self.first is None:
            print("List is empty")
        else:
            temp = self.first
            while temp is not None:
                print(temp.info, "  ", end='')
                temp = temp.next
            print("")

lst = SLList()

while True:
    print("1. Insert at beginning")
    print("2. Insert at end")
    print("3. Insert at specific position")
    print("4. Delete first node")
    print("5. Delete last node")
    print("6. Delete node at specific position")
    print("7. Search element")
    print("8. Display list")
    print("9. Exit")
    choice = int(input("Enter your choice: "))
    if choice == 9:
      break
    elif choice == 1:
      element = int(input("Enter element to be inserted: "))
      lst.insert(element, 1)
    elif choice == 2:
      element = int(input("Enter element to be inserted: "))
      lst.insert(element)
    elif choice == 3:
      element = int(input("Enter element to be inserted: "))
      pos = int(input("Enter position at which element is to be inserted: "))
      lst.insert(element,pos)
    elif choice == 4:
      lst.delete(1)
    elif choice == 5:
      lst.delete(lst.length)
    elif choice == 6:
      pos = int(input("Enter position of element to be deleted: "))
      lst.delete(pos)
    elif choice == 7:
      element = int(input("Enter element to search: "))
      lst.search(element)
    elif choice == 8:
      lst.display()
    else:
      print("Wrong choice")
      print("Bye!")
# Out:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at specific position
# 4. Delete first node
# 5. Delete last node
# 6. Delete node at specific position
# 7. Search element
# 8. Display list
# 9. Exit
# Enter your choice: 1
# Enter element to be inserted: 100
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at specific position
# 4. Delete first node
# 5. Delete last node
# 6. Delete node at specific position
# 7. Search element
# 8. Display list
# 9. Exit
# Enter your choice: 2
# Enter element to be inserted: 200
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at specific position
# 4. Delete first node
# 5. Delete last node
# 6. Delete node at specific position
# 7. Search element
# 8. Display list
# 9. Exit
# Enter your choice: 8
# 100   200
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at specific position
# 4. Delete first node
# 5. Delete last node
# 6. Delete node at specific position
# 7. Search element
# 8. Display list
# 9. Exit
# Enter your choice: 5
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at specific position
# 4. Delete first node
# 5. Delete last node
# 6. Delete node at specific position
# 7. Search element
# 8. Display list
# 9. Exit
# Enter your choice: 8
# 100
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at specific position
# 4. Delete first node
# 5. Delete last node
# 6. Delete node at specific position
# 7. Search element
# 8. Display list
# 9. Exit
# Enter your choice: 9

# %%
ab = [[1, 2], [2, 4]]
xy = ab
xy.append(67)
ab.append([55, 66])
ab[1][1] = 1000
print(ab)
print(xy)
# Out:
# [[1, 2], [2, 1000], 67, [55, 66]]
# [[1, 2], [2, 1000], 67, [55, 66]]

# %%
abc = [10,20,30]
xyz = abc
xyz.append(40)
print(abc)
print(xyz)

# %%
abc = [10,20,30]
xyz = abc[:]
xyz.append(40)
print(abc)
print(xyz)

# %%
import copy
abc = [10,20,30]
xyz = copy.deepcopy(abc)
xyz.append(40)
print(abc)
print(xyz)

# %%
a = [[1, 2], [2, 4]]
b = a[:]
a[0].append(3)
print(b)
print(a)

# %% [markdown]
# # THE END
